# %% [markdown]
# ### Question 8 - Using the data from Question 5, write code the analyze the data and answer the following questions
# Note -
#
# 1. Draw plots to demonstrate the analysis for the following questions and better visualizations
#
# 2. Write code comments wherever required for code understanding
#
# Insights to be drawn -
#
# ● Get all the overall ratings for each season and using plots compare the ratings for all the
# seasons, like season 1 ratings, season 2, and so on.
#
# ● Get all the episode names, whose average rating is more than 8 for every season
#
# ● Get all the episode names that aired before May 2019
#
# ● Get the episode name from each season with the highest and lowest rating
#
# ● Get the summary for the most popular ( ratings ) episode in every season

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('tvmaze.csv')

# %%
df
# Out:
#          id                                                url  \
# 0    869671  https://www.tvmaze.com/episodes/869671/westwor...
# 1    911201  https://www.tvmaze.com/episodes/911201/westwor...
# 2    911204  https://www.tvmaze.com/episodes/911204/westwor...
# 3    911205  https://www.tvmaze.com/episodes/911205/westwor...
# 4    927174  https://www.tvmaze.com/episodes/927174/westwor...
# 5    932057  https://www.tvmaze.com/episodes/932057/westwor...
# 6    938404  https://www.tvmaze.com/episodes/938404/westwor...
# 7    943065  https://www.tvmaze.com/episodes/943065/westwor...
# 8    943066  https://www.tvmaze.com/episodes/943066/westwor...
# 9    943067  https://www.tvmaze.com/episodes/943067/westwor...
# 10  1214222  https://www.tvmaze.com/episodes/1214222/westwo...
# 11  1440915  https://www.tvmaze.com/episodes/1440915/westwo...
# 12  1440916  https://www.tvmaze.com/episodes/1440916/westwo...
# 13  1440917  https://www.tvmaze.com/episodes/1440917/westwo...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   36 non-null     int64
#  1   url                  36 non-null     object
#  2   name                 36 non-null     object
#  3   season               36 non-null     int64
#  4   number               36 non-null     int64
#  5   type                 36 non-null     object
#  6   airdate              36 non-null     object
#  7   airtime              36 non-null     object
#  8   airstamp             36 non-null     object
#  9   runtime              36 non-null     float64
#  10  rating               36 non-null     float64
#  11  image                36 non-null     object
#  12  summary              36 non-null     object
#  13  _links               36 non-null     object
#  14  Medium Image link    36 non-null     object
# ...

# %% [markdown]
# ### ● Get all the overall ratings for each season and using plots compare the ratings for all the seasons, like season 1 ratings, season 2, and so on.

# %%
X = df.groupby('season')['rating'].sum()

# %%
X
# Out:
# season
# 1    80.9
# 2    80.0
# 3    62.2
# 4    60.3
# Name: rating, dtype: float64

# %%
plt.figure(figsize=(8,4))
plt.bar(['Season1','Season2','Season3','Season4'], X)
plt.show()

# %% [markdown]
# ### ● Get all the episode names, whose average rating is more than 8 for every season

# %%
df[df['rating']>8][['name','rating']]
# Out:
#                          name  rating
# 6               Trompe L'Oeil     8.6
# 8   The Well-Tempered Clavier     8.5
# 9          The Bicameral Mind     8.7
# 17                    Kiksuya     8.7
# 18            Vanishing Point     8.4
# 19              The Passenger     8.5

# %% [markdown]
# ### ● Get all the episode names that aired before May 2019

# %%
df['airdate'] = pd.to_datetime(df['airdate'])

# %%
df[df['airdate'] < pd.Timestamp('2019-05-01')][['name','airdate']]
# Out:
#                          name    airdate
# 0                The Original 2016-10-02
# 1                    Chestnut 2016-10-09
# 2                   The Stray 2016-10-16
# 3           Dissonance Theory 2016-10-23
# 4                 Contrapasso 2016-10-30
# 5               The Adversary 2016-11-06
# 6               Trompe L'Oeil 2016-11-13
# 7                 Trace Decay 2016-11-20
# 8   The Well-Tempered Clavier 2016-11-27
# 9          The Bicameral Mind 2016-12-04
# 10         Journey Into Night 2018-04-22
# 11                    Reunion 2018-04-29
# 12            Virtù e Fortuna 2018-05-06
# 13   The Riddle of the Sphinx 2018-05-13
# 14               Akane No Mai 2018-05-20
# 15                Phase Space 2018-05-27
# 16               Les Écorchés 2018-06-03
# 17                    Kiksuya 2018-06-10
# 18            Vanishing Point 2018-06-17
# 19              The Passenger 2018-06-24

# %% [markdown]
# ### Get the episode name from each season with the highest and lowest rating

# %%
df[['season','rating','name','id']]
# Out:
#     season  rating                       name       id
# 0        1     8.0               The Original   869671
# 1        1     7.7                   Chestnut   911201
# 2        1     7.6                  The Stray   911204
# 3        1     7.9          Dissonance Theory   911205
# 4        1     8.0                Contrapasso   927174
# 5        1     8.0              The Adversary   932057
# 6        1     8.6              Trompe L'Oeil   938404
# 7        1     7.9                Trace Decay   943065
# 8        1     8.5  The Well-Tempered Clavier   943066
# 9        1     8.7         The Bicameral Mind   943067
# 10       2     7.8         Journey Into Night  1214222
# 11       2     7.7                    Reunion  1440915
# 12       2     7.7            Virtù e Fortuna  1440916
# 13       2     8.0   The Riddle of the Sphinx  1440917
# 14       2     7.6               Akane No Mai  1446362
# 15       2     7.7                Phase Space  1453278
# ...

# %%
df.groupby(['season'])[['name','rating']].max()
# Out:
#                    name  rating
# season
# 1         Trompe L'Oeil     8.7
# 2       Virtù e Fortuna     8.7
# 3       The Winter Line     8.0
# 4              Zhuangzi     7.8

# %%
df.groupby(['season'])[['name','rating']].min()
# Out:
#                  name  rating
# season
# 1            Chestnut     7.6
# 2        Akane No Mai     7.6
# 3       Crisis Theory     7.5
# 4       Années Folles     7.1

# %% [markdown]
# ### ● Get the summary for the most popular ( ratings ) episode in every season

# %%
df.groupby(['season'])[['summary','rating']].max()
# Out:
#                                                   summary  rating
# season
# 1       While William and Dolores travel to the unclai...     8.7
# 2       William pays his recuperating father-in-law se...     8.7
# 3       Time to face the music. Dolores' true intentio...     8.0
# 4           You want to have a drink at a time like this?     7.8
